# %% [markdown]
# <a href="https://colab.research.google.com/github/Mani512996/pocs/blob/main/epl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
df = pd.read_csv('arsenal.csv')

# %%
df.head()
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0              Player     Nation        Pos        Age         MP
# 1  Gabriel Dos Santos     br BRA         DF     25-003         14
# 2      Aaron Ramsdale    eng ENG         GK     24-222         14
# 3      William Saliba     fr FRA         DF     21-273         14
# 4       Gabriel Jesus     br BRA         FW     25-263         14
#
#   Playing Time Playing Time.1 Playing Time.2 Performance Performance.1  ...  \
# 0       Starts            Min            90s         Gls           Ast  ...
# 1           14           1260             14           2             0  ...
# 2           14           1260             14           0             0  ...
# 3           14           1245           13.8           2             1  ...
# 4           14           1219           13.5           5             5  ...
#
#   Expected.1 Expected.2 Expected.3 Per 90 Minutes.5 Per 90 Minutes.6  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Playing Time  \
# count          31         29         29         31         31           31
# unique         31         16          7         31         13           11
# top        Player    eng ENG         DF        Age         14            0
# freq            1         10          9          1         10           12
#
#        Playing Time.1 Playing Time.2 Performance Performance.1  ...  \
# count              26             26          26            26  ...
# unique             22             21          10             9  ...
# top              1260             14           0             0  ...
# freq                4              4          13            13  ...
#
#        Expected.1 Expected.2 Expected.3 Per 90 Minutes.5 Per 90 Minutes.6  \
# count          26         26         26               26               26
# unique         15         16         19               15               20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        31 non-null     object
#  1   Unnamed: 1        29 non-null     object
#  2   Unnamed: 2        29 non-null     object
#  3   Unnamed: 3        31 non-null     object
#  4   Unnamed: 4        31 non-null     object
#  5   Playing Time      31 non-null     object
#  6   Playing Time.1    26 non-null     object
#  7   Playing Time.2    26 non-null     object
#  8   Performance       26 non-null     object
#  9   Performance.1     26 non-null     object
#  10  Performance.2     26 non-null     object
#  11  Performance.3     26 non-null     object
#  12  Performance.4     26 non-null     object
#  13  Performance.5     26 non-null     object
#  14  Performance.6     26 non-null     object
#  15  Per 90 Minutes    26 non-null     object
# ...

# %%
df1 = df.isnull().sum()

# %%
df1
# Out:
# Unnamed: 0          0
# Unnamed: 1          2
# Unnamed: 2          2
# Unnamed: 3          0
# Unnamed: 4          0
# Playing Time        0
# Playing Time.1      5
# Playing Time.2      5
# Performance         5
# Performance.1       5
# Performance.2       5
# Performance.3       5
# Performance.4       5
# Performance.5       5
# Performance.6       5
# Per 90 Minutes      5
# Per 90 Minutes.1    5
# Per 90 Minutes.2    5
# Per 90 Minutes.3    5
# Per 90 Minutes.4    5
# Expected            5
# Expected.1          5
# Expected.2          5
# Expected.3          5
# Per 90 Minutes.5    5
# Per 90 Minutes.6    5
# Per 90 Minutes.7    5
# Per 90 Minutes.8    5
# Per 90 Minutes.9    5
# Unnamed: 29         2
# -additional         0
# dtype: int64

# %%
df.p
